# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D

# %%
death_toll = pd.read_csv('avg_deaths.csv')
death_toll
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]
plt.show()

# %% [markdown]
# ### Now we remove tick lables

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.show()

# %% [markdown]
# ### Now removing Ticks

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#D22B2B", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#D22B2B", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#D22B2B", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#D22B2B", weight = "bold", rotation = 45)

plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#D22B2B", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#D22B2B", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#D22B2B", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#D22B2B", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3150, "Average Number of daily deaths per month in the US", size = 12)

plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#D22B2B", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#D22B2B", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#D22B2B", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#D22B2B", weight = "bold", rotation = 45)

ax1.text(0.5, 3600, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3200, "Average Number of daily deaths per month in the US", size = 12)

for ax in axes:
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3 )
    
plt.show()

# %%
deaths = []
end = 3

for i in range(4):
    deaths.append(death_toll["New_deaths"][:end].sum())
    end += 3
deaths.
# Out:
# [77, 4154, 6682, 10905]

# %%
0.3-0.9
# Out:
# -0.6000000000000001

# %%
0.9 + (10905/19005) * -0.6
# Out:
# 0.5557221783741122

# %%
proportions = [round(death/10905,2) for death in deaths]
proportions
# Out:
# [0.01, 0.38, 0.61, 1.0]

# %%
ymax_vals = [0.9 + proportion * (-0.6) for proportion in proportions]
ymax_vals
# Out:
# [0.894, 0.672, 0.534, 0.30000000000000004]

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#D22B2B", weight = "bold", rotation = 3)
ax2.text(3.7, 700, "Mar - Jun", color = "#D22B2B", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#D22B2B", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#D22B2B", weight = "bold", rotation = 50)

ax1.text(0.5, 3600, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3200, "Average Number of daily deaths per month in the US", size = 12)

for ax in axes:
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3)

for ax,ymax in zip(axes, ymax_vals):
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3)
    ax.axvline(x = 14, ymin = 0.9, ymax = ymax, linewidth = 12, color = "#D22B2B", alpha = 1 )

    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#D22B2B", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#D22B2B", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#D22B2B", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#D22B2B", weight = "bold", rotation = 45)

ax1.text(0.5, 3600, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3200, "Average Number of daily deaths per month in the US", size = 12)

for ax in axes:
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3)

for ax,ymax,death in zip(axes, ymax_vals,deaths):
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3)
    ax.axvline(x = 14, ymin = 0.9, ymax = ymax, linewidth = 12, color = "#D22B2B", alpha = 1 )
    ax.text(14.5, 1400, format(death,","),  color = "#D22B2B", weight = "bold")
    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4 , ncols = 1 , figsize=(6,8))
axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#D22B2B" , alpha = 0.36)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0 , left = 0)

    for location in ["right", "left", "bottom", "top"]:
        ax.spines[location].set_visible(False)
ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#D22B2B" , linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#D22B2B" , linewidth = 2.5)
ax3.plot(death_toll["Month"][5:9], death_toll["New_deaths"][5:9], color = "#D22B2B" , linewidth = 2.5)
ax4.plot(death_toll["Month"][8:], death_toll["New_deaths"][8:], color = "#D22B2B" , linewidth = 2.5)

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#D22B2B", weight = "bold", rotation = 3)
ax2.text(3.7, 700, "Mar - Jun", color = "#D22B2B", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#D22B2B", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#D22B2B", weight = "bold", rotation = 50)

ax1.text(0.5, 3600, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3200, "Average Number of daily deaths per month in the US", size = 12)

for ax in axes:
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3)

for ax,ymax,death in zip(axes, ymax_vals,deaths):
    ax.axvline(x = 14, ymin = 0.9, ymax = 0.3, linewidth = 12, color = "#D22B2B", alpha = 0.3)
    ax.axvline(x = 14, ymin = 0.9, ymax = ymax, linewidth = 12, color = "#D22B2B", alpha = 1 )
    ax.text(14.5, 1400, format(death,","),  color = "#D22B2B", weight = "bold")
    

plt.savefig("storytelling2.jpeg")
plt.show()
