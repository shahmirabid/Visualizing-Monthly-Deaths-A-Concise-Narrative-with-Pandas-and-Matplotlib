# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
death_toll = pd.read_csv("avg_deaths.csv")

# %%
death_toll
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.2)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
        
        
ax1.plot(death_toll["Month"][:3],death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6],death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10],death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12],death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
    
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.2)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
        
        
ax1.plot(death_toll["Month"][:3],death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6],death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10],death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12],death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
  

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.2)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
        
        
ax1.plot(death_toll["Month"][:3],death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6],death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10],death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12],death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
  

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3150, "Average Number of daily deaths per month per month in the US", size = 12)

plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.2)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
        
        
ax1.plot(death_toll["Month"][:3],death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6],death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10],death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12],death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
  

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3150, "Average Number of daily deaths per month per month in the US", size = 12)

for ax in axes:
    ax.axvline(x = 13, ymin = 0.5, ymax = 0.8, linewidth = 7, color = "#af0b1e", alpha = 0.3)

plt.show()

# %%
0.8 - 0.5
# Out:
# 0.30000000000000004

# %%
death_toll["New_deaths"][:3].sum()
# Out:
# 77

# %%
deaths = []
end = 3

for i in range(4):
    print(death_toll["New_deaths"][:end])
    end += 3
    print("*" * 30)
# Out:
# 0     0
# 1     0
# 2    77
# Name: New_deaths, dtype: int64
# ******************************
# 0       0
# 1       0
# 2      77
# 3    1844
# 4    1448
# 5     785
# Name: New_deaths, dtype: int64
# ******************************
# 0       0
# 1       0
# 2      77
# 3    1844
# 4    1448
# 5     785
# 6     769
# 7    1020
# 8     739
# Name: New_deaths, dtype: int64
# ******************************
# 0        0
# 1        0
# 2       77
# 3     1844
# 4     1448
# 5      785
# 6      769
# 7     1020
# 8      739
# 9      751
# 10    1225
# 11    2247
# Name: New_deaths, dtype: int64
# ******************************

# %%
deaths = []
end = 3

for i in range(4):
    deaths.append(death_toll["New_deaths"][:end].sum())
    end += 3

# %%
deaths
# Out:
# [77, 4154, 6682, 10905]

# %%
0.5 + (10905/10905) * 0.3
# Out:
# 0.8

# %%
proportions = [round(death/10905,2) for death in deaths]
proportions
# Out:
# [0.01, 0.38, 0.61, 1.0]

# %%
ymax_vals = [0.5 + proportion * 0.3 for proportion in proportions]
ymax_vals
# Out:
# [0.503, 0.614, 0.683, 0.8]

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.2)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
        
        
ax1.plot(death_toll["Month"][:3],death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6],death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10],death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12],death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
  

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3150, "Average Number of daily deaths per month per month in the US", size = 12)


for ax,ymax in zip(axes, ymax_vals):
    ax.axvline(x = 13, ymin = 0.5, ymax = 0.8, linewidth = 7, color = "#af0b1e", alpha = 0.3)
    ax.axvline(x = 13, ymin = 0.5, ymax = ymax, linewidth = 7, color = "#af0b1e", alpha = 1)
    

plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(nrows = 4, ncols = 1,  figsize=(6,8))

axes = [ax1,ax2,ax3,ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.2)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right", "top","bottom"]:
        ax.spines[location].set_visible(False)
        
        
ax1.plot(death_toll["Month"][:3],death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6],death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10],death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12],death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
  

ax1.text(0.5, -80, "0", alpha = 0.5)
ax1.text(11.5, 2400, "2,247", alpha = 0.5)

ax2.text(0.5, -80, "0", alpha = 0.5)
ax2.text(11.5, 2400, "2,247", alpha = 0.5)

ax3.text(0.5, -80, "0", alpha = 0.5)
ax3.text(11.5, 2400, "2,247", alpha = 0.5)

ax4.text(0.5, -80, "0", alpha = 0.5)
ax4.text(11.5, 2400, "2,247", alpha = 0.5)

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

ax1.text(0.5, 3500, "The Virus Kills 851 people each day", size = 14, weight = "bold")
ax1.text(0.5, 3150, "Average Number of daily deaths per month per month in the US", size = 12)

for ax,ymax,death in zip(axes, ymax_vals, deaths):
    ax.axvline(x = 13, ymin = 0.5, ymax = 0.8, linewidth = 7, color = "#af0b1e", alpha = 0.3)
    ax.axvline(x = 13, ymin = 0.5, ymax = ymax, linewidth = 7, color = "#af0b1e", alpha = 1)
    ax.text(13.5, 1400, format(death,","),  color = "#af0b1e", weight = "bold")


plt.savefig("Story_telling.jpeg")
plt.show()

# %%
for pro, xmax in zip(proportions, xmax_vals):
    print(pro, xmax)
# Out:
# 0.01 0.503
# 0.38 0.614
# 0.61 0.683
# 1.0 0.8

# %%
format(deaths[-1],",")
# Out:
# '10,905'
